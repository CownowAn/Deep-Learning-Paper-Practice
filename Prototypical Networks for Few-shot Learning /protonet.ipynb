# %%
# mounting google drive to colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
import torch.nn.functional as F
import numpy as np
from tqdm import tqdm

# %%
import easydict

args = easydict.EasyDict({
    'root': 'data', # path to dataset
    'results_root': 'results', # root to store models, loss and accuracies
    'epochs': 20,
    'learning_rate': 0.001,
    'lr_scheduler_step': 20, # per 2000iterations, lr *= gamma (1epoch: 100iterations)
    'lr_scheduler_gamma': 0.5,
    'iterations': 100,
    'Nc_train': 60,
    'Ns_train': 5,
    'Nq_train': 5,
    'Nc_test': 5,
    'Ns_test': 5,
    'Nq_test': 15,
    'manual_seed': 423,
    'use_cuda': True
})

device = torch.device('cuda' if torch.cuda.is_available() and args.use_cuda else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Seed

# %%
torch.cuda.cudnn_enabled = False

seed = args.manual_seed
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
if not os.path.exists(args.results_root):
  os.makedirs(args.results_root)
if not os.path.exists(args.root):
  os.makedirs(args.root)

# %% [markdown]
# # Dataset

# %%
from torchvision.datasets import Omniglot
import torchvision.transforms as transforms

transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Resize(28)
                                ])

train_val_dataset = Omniglot(root=args.root+'/train', background=True, transform=transform, download=True)
test_dataset = Omniglot(root=args.root+'/test', background=False, transform=transform, download=True)
# Out:
# Downloading https://raw.githubusercontent.com/brendenlake/omniglot/master/python/images_background.zip to data/train/omniglot-py/images_background.zip
#   0%|          | 0/9464212 [00:00<?, ?it/s]
# Extracting data/train/omniglot-py/images_background.zip to data/train/omniglot-py
# Downloading https://raw.githubusercontent.com/brendenlake/omniglot/master/python/images_evaluation.zip to data/test/omniglot-py/images_evaluation.zip
#   0%|          | 0/6462886 [00:00<?, ?it/s]
# Extracting data/test/omniglot-py/images_evaluation.zip to data/test/omniglot-py

# %%
# Check
train_val_dataset[0][1]
# Out:
# 0

# %%
# Get labels for dataset
def get_labels(dataset):
  labels = list()
  for i in range(len(dataset)):
    labels.append(dataset[i][1])
  return labels

# %%
train_val_dataset_labels = get_labels(train_val_dataset)

# %%
from sklearn.model_selection import train_test_split

train_indices, val_indices = train_test_split((range(len(train_val_dataset_labels))), test_size=0.25, shuffle=False)

train_dataset = torch.utils.data.Subset(train_val_dataset, train_indices)
val_dataset = torch.utils.data.Subset(train_val_dataset, val_indices)

# %%
train_dataset_labels = get_labels(train_dataset)
val_dataset_labels = get_labels(val_dataset)
test_dataset_labels = get_labels(test_dataset)

# %% [markdown]
# # BatchSampler

# %%
import numpy as np
import torch

class ProtoBatchSampler(object):

  def __init__(self, labels, Nc, num_samples, iterations):
    """
    labels: dataset labels
    Nc: number of classes 
    num_samples = Ns + Nq
    iterations: number of iterations per epoch
    """
    super(ProtoBatchSampler, self).__init__()
    self.labels = labels
    self.Nc = Nc
    self.num_samples = num_samples
    self.iterations = iterations

    self.classes, self.counts_per_class = np.unique(self.labels, return_counts=True)
    self.classes = torch.LongTensor(self.classes)
    self.indices_by_class = torch.Tensor(np.empty((len(self.classes), max(self.counts_per_class))) * np.nan)
    for data_idx, label in enumerate(self.labels):
      row_idx = np.argwhere(self.classes == label).item()
      col_idx = np.where(np.isnan(self.indices_by_class[row_idx]))[0][0].item()
      self.indices_by_class[row_idx, col_idx] = data_idx
  
  def __iter__(self):
    for it in range(self.iterations):
      batch_size = self.Nc * self.num_samples
      batch = torch.LongTensor(batch_size)
      selected_class_indices = torch.randperm(len(self.classes))[:self.Nc]
      for i, c in enumerate(self.classes[selected_class_indices]):
        batch_indices = slice(i*self.num_samples, (i+1)*self.num_samples)
        row_idx = np.argwhere(self.classes == c).item()
        sample_indices = torch.randperm(self.counts_per_class[row_idx])[:self.num_samples]
        batch[batch_indices] = self.indices_by_class[row_idx][sample_indices]
      batch = batch[torch.randperm(batch_size)]
      yield batch
  
  def __len__(self):
    return self.iterations

# %%
train_sampler = ProtoBatchSampler(labels=train_dataset_labels,
                                         Nc=args.Nc_train, 
                                         num_samples=args.Ns_train + args.Nq_train, 
                                         iterations=args.iterations)
val_sampler = ProtoBatchSampler(labels=val_dataset_labels,
                                       Nc=args.Nc_test,
                                       num_samples=args.Ns_test + args.Nq_test,
                                       iterations=args.iterations)
test_sampler = ProtoBatchSampler(labels=test_dataset_labels, 
                                        Nc=args.Nc_test, 
                                        num_samples=args.Ns_test + args.Nq_test,
                                        iterations=args.iterations)

# %% [markdown]
# # DataLoader

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(dataset=train_dataset,
                              batch_sampler=train_sampler)

val_dataloader = DataLoader(dataset=val_dataset,
                            batch_sampler=val_sampler)

test_dataloader = DataLoader(dataset=test_dataset,
                             batch_sampler=test_sampler)

# %% [markdown]
# # Protonet architecture

# %%
import torch.nn as nn

def conv_block(in_channels, out_channels):
  return nn.Sequential(
      nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
      nn.BatchNorm2d(out_channels),
      nn.ReLU(),
      nn.MaxPool2d(2)
  )

class Protonet(nn.Module):

  def __init__(self, in_channels=1, out_channels=64):
    super(Protonet, self).__init__()
    self.embedding = nn.Sequential(
        conv_block(in_channels, out_channels),
        conv_block(out_channels, out_channels),
        conv_block(out_channels, out_channels),
        conv_block(out_channels, out_channels)
    )
  
  def forward(self, x):
    out = self.embedding(x)
    out = out.view(x.size(0), -1)
    return out

# %%
model = Protonet()
model.to(device)
# Out:
# Protonet(
#   (embedding): Sequential(
#     (0): Sequential(
#       (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (3): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#   )
# )

# %% [markdown]
# # Loss function

# %%
import torch
import torch.nn.functional as F

def euclidean_distance(x, y):
  """
  x, y is either query_embedded or prototypes
  x: [N, D]
  y: [M, D]
  """
  if x.size(1) != y.size(1):
    raise Exception
  N = x.size(0)
  M = y.size(0)
  D = x.size(1)
  # Make both tensors to [N, M, D] shape
  x = x.unsqueeze(1).expand(N, M, D)
  y = y.unsqueeze(0).expand(N, M, D)
  # Calculate euclidean distance between x and y
  dist = torch.pow(x-y, 2).sum(dim=2) # [N, M]
  return dist

def proto_loss(input, target, Ns, Nq):
  """
  input(torch.Tensor): [num_samples, embedded_dim]
  target(torch.LongTensor): [num_samples, ]
  """
  input = input.to('cpu')
  target = target.to('cpu') # class label

  def supportset_select(class_idx):
    return target.eq(class_idx).nonzero()[:Ns].squeeze(1) # 1D tensor
  
  def query_select(class_idx):
    return target.eq(class_idx).nonzero()[Ns:].squeeze(1)

  class_indices = torch.unique(target)
  Nc = len(class_indices)

  supportset_indices = list(map(supportset_select, class_indices))
  prototypes = torch.stack([input[supportset_idx].mean(0) for supportset_idx in supportset_indices])

  query_indices = torch.stack(list(map(query_select, class_indices))).view(-1)
  query_samples = input[query_indices]
  
  dists = euclidean_distance(query_samples, prototypes) # [Nc*Nq, Nc]
  log_p = F.log_softmax(-dists, dim=1).view(Nc, Nq, -1)

  target_indices = torch.arange(Nc)
  target_indices = target_indices.view(Nc, 1, 1)
  target_indices = target_indices.expand(Nc, Nq, 1).long()

  loss = -log_p.gather(2, target_indices).squeeze().view(-1).mean()
  _, predict = log_p.max(2)
  acc = predict.eq(target_indices.squeeze()).float().mean()
  
  return loss, acc

# %% [markdown]
# # Optimizer & lr_scheduler

# %%
optimizer = torch.optim.Adam(params=model.parameters(), lr=args.learning_rate)

lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer,
                                            gamma=args.lr_scheduler_gamma,
                                            step_size=args.lr_scheduler_step)

# %% [markdown]
# # Train

# %%
def train(model, dataloader, epoch):
  model.train()

  train_loss = []
  train_acc = []
  log_interval = 20
  
  for it, (inputs, targets) in enumerate(dataloader):
    optimizer.zero_grad()

    inputs = inputs.to(device)
    targets = targets.to(device)
    
    outs = model(inputs)
    loss, acc = proto_loss(outs, targets, args.Ns_train, args.Nq_train)
    train_loss.append(loss.item())
    train_acc.append(acc.item())

    loss.backward()
    optimizer.step()

    if it % log_interval == 0 and it > 0:
      print(f"| epoch {epoch:3d} | {it:5d}/{len(dataloader):5d} iteration | loss {loss:8.3f} | accuracy {acc:8.3f}")

  train_loss_epoch = np.mean(train_loss)
  train_acc_epoch = np.mean(train_acc)

  lr_scheduler.step()

# %% [markdown]
# # Validate

# %%
def validate(model, dataloader):
  with torch.no_grad():
    model.eval()

    val_loss = []
    val_acc = []
    log_interval = 20

    for it, (inputs, targets) in enumerate(dataloader):
      inputs = inputs.to(device)
      targets = targets.to(device)

      outs = model(inputs)
      loss, acc = proto_loss(outs, targets, args.Ns_test, args.Nq_test)
      val_loss.append(loss.item())
      val_acc.append(acc.item())

      if it % log_interval == 0 and it > 0:
        print(f"| {it:5d}/{len(dataloader):5d} iteration | loss {loss:8.3f} | accuracy {acc:8.3f}")
    
    val_loss_epoch = np.mean(val_loss)
    val_acc_epoch = np.mean(val_acc)
    return val_loss_epoch, val_acc_epoch

# %%
best_acc = 0
best_state = None
for epoch in range(1, args.epochs + 1):
  print(f"========== Epoch: {epoch} ==========")
  print("Train")
  train(model, train_dataloader, epoch)
  print("Validation")
  val_loss_epoch, val_acc_epoch = validate(model, val_dataloader)

  print('-' * 70)
  if best_acc < val_acc_epoch:
    best_acc = val_acc_epoch
    best_state = model.state_dict()
    print(f"best validation accuracy {best_acc:8.3f}")
    torch.save(model.state_dict(), f"{args.results_root}/best_model.pth")
  
  print(f"| end of epoch {epoch:3d} | best accuracy {best_acc:8.3f}")
  
  print('=' * 70)
# Out:
# ========== Epoch: 1 ==========
# Train
# | epoch   1 |    20/  100 iteration | loss    0.562 | accuracy    0.860
# | epoch   1 |    40/  100 iteration | loss    0.278 | accuracy    0.923
# | epoch   1 |    60/  100 iteration | loss    0.322 | accuracy    0.890
# | epoch   1 |    80/  100 iteration | loss    0.322 | accuracy    0.900
# Validation
# |    20/  100 iteration | loss    0.201 | accuracy    0.907
# |    40/  100 iteration | loss    0.013 | accuracy    1.000
# |    60/  100 iteration | loss    0.004 | accuracy    1.000
# |    80/  100 iteration | loss    0.088 | accuracy    0.960
# ----------------------------------------------------------------------
# best validation accuracy    0.976
# | end of epoch   1 | best accuracy    0.976
# ======================================================================
# ========== Epoch: 2 ==========
# Train
# | epoch   2 |    20/  100 iteration | loss    0.159 | accuracy    0.943
# | epoch   2 |    40/  100 iteration | loss    0.156 | accuracy    0.940
# | epoch   2 |    60/  100 iteration | loss    0.272 | accuracy    0.903
# | epoch   2 |    80/  100 iteration | loss    0.211 | accuracy    0.933
# Validation
# |    20/  100 iteration | loss    0.001 | accuracy    1.000
# |    40/  100 iteration | loss    0.120 | accuracy    0.960
# |    60/  100 iteration | loss    0.002 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# best validation accuracy    0.987
# | end of epoch   2 | best accuracy    0.987
# ======================================================================
# ========== Epoch: 3 ==========
# Train
# | epoch   3 |    20/  100 iteration | loss    0.133 | accuracy    0.957
# | epoch   3 |    40/  100 iteration | loss    0.149 | accuracy    0.957
# | epoch   3 |    60/  100 iteration | loss    0.064 | accuracy    0.983
# | epoch   3 |    80/  100 iteration | loss    0.107 | accuracy    0.967
# Validation
# |    20/  100 iteration | loss    0.034 | accuracy    0.987
# |    40/  100 iteration | loss    0.096 | accuracy    0.973
# |    60/  100 iteration | loss    0.001 | accuracy    1.000
# |    80/  100 iteration | loss    0.013 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch   3 | best accuracy    0.987
# ======================================================================
# ========== Epoch: 4 ==========
# Train
# | epoch   4 |    20/  100 iteration | loss    0.102 | accuracy    0.963
# | epoch   4 |    40/  100 iteration | loss    0.115 | accuracy    0.967
# | epoch   4 |    60/  100 iteration | loss    0.116 | accuracy    0.967
# | epoch   4 |    80/  100 iteration | loss    0.127 | accuracy    0.953
# Validation
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.031 | accuracy    0.987
# |    60/  100 iteration | loss    0.001 | accuracy    1.000
# |    80/  100 iteration | loss    0.104 | accuracy    0.987
# ----------------------------------------------------------------------
# best validation accuracy    0.988
# | end of epoch   4 | best accuracy    0.988
# ======================================================================
# ========== Epoch: 5 ==========
# Train
# | epoch   5 |    20/  100 iteration | loss    0.202 | accuracy    0.910
# | epoch   5 |    40/  100 iteration | loss    0.064 | accuracy    0.983
# | epoch   5 |    60/  100 iteration | loss    0.112 | accuracy    0.957
# | epoch   5 |    80/  100 iteration | loss    0.149 | accuracy    0.933
# Validation
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.000 | accuracy    1.000
# |    60/  100 iteration | loss    0.020 | accuracy    0.987
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# best validation accuracy    0.988
# | end of epoch   5 | best accuracy    0.988
# ======================================================================
# ========== Epoch: 6 ==========
# Train
# | epoch   6 |    20/  100 iteration | loss    0.089 | accuracy    0.970
# | epoch   6 |    40/  100 iteration | loss    0.056 | accuracy    0.980
# | epoch   6 |    60/  100 iteration | loss    0.071 | accuracy    0.970
# | epoch   6 |    80/  100 iteration | loss    0.114 | accuracy    0.957
# Validation
# |    20/  100 iteration | loss    0.236 | accuracy    0.987
# |    40/  100 iteration | loss    0.000 | accuracy    1.000
# |    60/  100 iteration | loss    0.003 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# best validation accuracy    0.991
# | end of epoch   6 | best accuracy    0.991
# ======================================================================
# ========== Epoch: 7 ==========
# Train
# | epoch   7 |    20/  100 iteration | loss    0.092 | accuracy    0.973
# | epoch   7 |    40/  100 iteration | loss    0.105 | accuracy    0.963
# | epoch   7 |    60/  100 iteration | loss    0.032 | accuracy    0.990
# | epoch   7 |    80/  100 iteration | loss    0.043 | accuracy    0.987
# Validation
# |    20/  100 iteration | loss    0.001 | accuracy    1.000
# |    40/  100 iteration | loss    0.004 | accuracy    1.000
# |    60/  100 iteration | loss    0.000 | accuracy    1.000
# |    80/  100 iteration | loss    0.085 | accuracy    0.960
# ----------------------------------------------------------------------
# best validation accuracy    0.991
# | end of epoch   7 | best accuracy    0.991
# ======================================================================
# ========== Epoch: 8 ==========
# Train
# | epoch   8 |    20/  100 iteration | loss    0.068 | accuracy    0.980
# | epoch   8 |    40/  100 iteration | loss    0.103 | accuracy    0.967
# | epoch   8 |    60/  100 iteration | loss    0.073 | accuracy    0.970
# | epoch   8 |    80/  100 iteration | loss    0.051 | accuracy    0.980
# Validation
# |    20/  100 iteration | loss    0.115 | accuracy    0.987
# |    40/  100 iteration | loss    0.002 | accuracy    1.000
# |    60/  100 iteration | loss    0.058 | accuracy    0.987
# |    80/  100 iteration | loss    0.001 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch   8 | best accuracy    0.991
# ======================================================================
# ========== Epoch: 9 ==========
# Train
# | epoch   9 |    20/  100 iteration | loss    0.019 | accuracy    0.997
# | epoch   9 |    40/  100 iteration | loss    0.038 | accuracy    0.990
# | epoch   9 |    60/  100 iteration | loss    0.106 | accuracy    0.963
# | epoch   9 |    80/  100 iteration | loss    0.041 | accuracy    0.983
# Validation
# |    20/  100 iteration | loss    0.002 | accuracy    1.000
# |    40/  100 iteration | loss    0.011 | accuracy    0.987
# |    60/  100 iteration | loss    0.001 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch   9 | best accuracy    0.991
# ======================================================================
# ========== Epoch: 10 ==========
# Train
# | epoch  10 |    20/  100 iteration | loss    0.095 | accuracy    0.967
# | epoch  10 |    40/  100 iteration | loss    0.052 | accuracy    0.977
# | epoch  10 |    60/  100 iteration | loss    0.055 | accuracy    0.983
# | epoch  10 |    80/  100 iteration | loss    0.057 | accuracy    0.973
# Validation
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.038 | accuracy    0.973
# |    60/  100 iteration | loss    0.000 | accuracy    1.000
# |    80/  100 iteration | loss    0.131 | accuracy    0.973
# ----------------------------------------------------------------------
# | end of epoch  10 | best accuracy    0.991
# ======================================================================
# ========== Epoch: 11 ==========
# Train
# | epoch  11 |    20/  100 iteration | loss    0.072 | accuracy    0.973
# | epoch  11 |    40/  100 iteration | loss    0.063 | accuracy    0.963
# | epoch  11 |    60/  100 iteration | loss    0.040 | accuracy    0.987
# | epoch  11 |    80/  100 iteration | loss    0.106 | accuracy    0.967
# Validation
# |    20/  100 iteration | loss    0.031 | accuracy    0.987
# |    40/  100 iteration | loss    0.000 | accuracy    1.000
# |    60/  100 iteration | loss    0.000 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# best validation accuracy    0.994
# | end of epoch  11 | best accuracy    0.994
# ======================================================================
# ========== Epoch: 12 ==========
# Train
# | epoch  12 |    20/  100 iteration | loss    0.027 | accuracy    0.990
# | epoch  12 |    40/  100 iteration | loss    0.045 | accuracy    0.987
# | epoch  12 |    60/  100 iteration | loss    0.042 | accuracy    0.983
# | epoch  12 |    80/  100 iteration | loss    0.092 | accuracy    0.980
# Validation
# |    20/  100 iteration | loss    0.045 | accuracy    0.973
# |    40/  100 iteration | loss    0.000 | accuracy    1.000
# |    60/  100 iteration | loss    0.001 | accuracy    1.000
# |    80/  100 iteration | loss    0.039 | accuracy    0.987
# ----------------------------------------------------------------------
# | end of epoch  12 | best accuracy    0.994
# ======================================================================
# ========== Epoch: 13 ==========
# Train
# | epoch  13 |    20/  100 iteration | loss    0.033 | accuracy    0.987
# | epoch  13 |    40/  100 iteration | loss    0.039 | accuracy    0.980
# | epoch  13 |    60/  100 iteration | loss    0.062 | accuracy    0.970
# | epoch  13 |    80/  100 iteration | loss    0.056 | accuracy    0.980
# Validation
# |    20/  100 iteration | loss    0.005 | accuracy    1.000
# |    40/  100 iteration | loss    0.001 | accuracy    1.000
# |    60/  100 iteration | loss    0.000 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch  13 | best accuracy    0.994
# ======================================================================
# ========== Epoch: 14 ==========
# Train
# | epoch  14 |    20/  100 iteration | loss    0.056 | accuracy    0.973
# | epoch  14 |    40/  100 iteration | loss    0.033 | accuracy    0.987
# | epoch  14 |    60/  100 iteration | loss    0.027 | accuracy    0.990
# | epoch  14 |    80/  100 iteration | loss    0.022 | accuracy    0.990
# Validation
# |    20/  100 iteration | loss    0.010 | accuracy    1.000
# |    40/  100 iteration | loss    0.010 | accuracy    1.000
# |    60/  100 iteration | loss    0.181 | accuracy    0.987
# |    80/  100 iteration | loss    0.012 | accuracy    0.987
# ----------------------------------------------------------------------
# | end of epoch  14 | best accuracy    0.994
# ======================================================================
# ========== Epoch: 15 ==========
# Train
# | epoch  15 |    20/  100 iteration | loss    0.066 | accuracy    0.970
# | epoch  15 |    40/  100 iteration | loss    0.027 | accuracy    0.990
# | epoch  15 |    60/  100 iteration | loss    0.083 | accuracy    0.970
# | epoch  15 |    80/  100 iteration | loss    0.025 | accuracy    0.990
# Validation
# |    20/  100 iteration | loss    0.004 | accuracy    1.000
# |    40/  100 iteration | loss    0.000 | accuracy    1.000
# |    60/  100 iteration | loss    0.001 | accuracy    1.000
# |    80/  100 iteration | loss    0.002 | accuracy    1.000
# ----------------------------------------------------------------------
# best validation accuracy    0.995
# | end of epoch  15 | best accuracy    0.995
# ======================================================================
# ========== Epoch: 16 ==========
# Train
# | epoch  16 |    20/  100 iteration | loss    0.035 | accuracy    0.987
# | epoch  16 |    40/  100 iteration | loss    0.085 | accuracy    0.963
# | epoch  16 |    60/  100 iteration | loss    0.051 | accuracy    0.977
# | epoch  16 |    80/  100 iteration | loss    0.025 | accuracy    0.993
# Validation
# |    20/  100 iteration | loss    0.019 | accuracy    0.987
# |    40/  100 iteration | loss    0.012 | accuracy    1.000
# |    60/  100 iteration | loss    0.008 | accuracy    1.000
# |    80/  100 iteration | loss    0.026 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch  16 | best accuracy    0.995
# ======================================================================
# ========== Epoch: 17 ==========
# Train
# | epoch  17 |    20/  100 iteration | loss    0.016 | accuracy    0.993
# | epoch  17 |    40/  100 iteration | loss    0.031 | accuracy    0.990
# | epoch  17 |    60/  100 iteration | loss    0.018 | accuracy    0.993
# | epoch  17 |    80/  100 iteration | loss    0.016 | accuracy    0.997
# Validation
# |    20/  100 iteration | loss    0.002 | accuracy    1.000
# |    40/  100 iteration | loss    0.004 | accuracy    1.000
# |    60/  100 iteration | loss    0.008 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch  17 | best accuracy    0.995
# ======================================================================
# ========== Epoch: 18 ==========
# Train
# | epoch  18 |    20/  100 iteration | loss    0.032 | accuracy    0.990
# | epoch  18 |    40/  100 iteration | loss    0.022 | accuracy    0.993
# | epoch  18 |    60/  100 iteration | loss    0.056 | accuracy    0.970
# | epoch  18 |    80/  100 iteration | loss    0.033 | accuracy    0.997
# Validation
# |    20/  100 iteration | loss    0.064 | accuracy    0.973
# |    40/  100 iteration | loss    0.003 | accuracy    1.000
# |    60/  100 iteration | loss    0.033 | accuracy    0.973
# |    80/  100 iteration | loss    0.001 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch  18 | best accuracy    0.995
# ======================================================================
# ========== Epoch: 19 ==========
# Train
# | epoch  19 |    20/  100 iteration | loss    0.020 | accuracy    0.990
# | epoch  19 |    40/  100 iteration | loss    0.047 | accuracy    0.977
# | epoch  19 |    60/  100 iteration | loss    0.120 | accuracy    0.950
# | epoch  19 |    80/  100 iteration | loss    0.048 | accuracy    0.980
# Validation
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.088 | accuracy    0.987
# |    60/  100 iteration | loss    0.004 | accuracy    1.000
# |    80/  100 iteration | loss    0.017 | accuracy    0.987
# ----------------------------------------------------------------------
# | end of epoch  19 | best accuracy    0.995
# ======================================================================
# ========== Epoch: 20 ==========
# Train
# | epoch  20 |    20/  100 iteration | loss    0.034 | accuracy    0.993
# | epoch  20 |    40/  100 iteration | loss    0.048 | accuracy    0.977
# | epoch  20 |    60/  100 iteration | loss    0.012 | accuracy    1.000
# | epoch  20 |    80/  100 iteration | loss    0.049 | accuracy    0.987
# Validation
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.042 | accuracy    0.987
# |    60/  100 iteration | loss    0.051 | accuracy    0.987
# |    80/  100 iteration | loss    0.005 | accuracy    1.000
# ----------------------------------------------------------------------
# | end of epoch  20 | best accuracy    0.995
# ======================================================================

# %%
model.load_state_dict(best_state)

test_loss, test_acc = validate(model, test_dataloader)

print(f"Test loss: {test_loss:8.3f} | Test acc: {test_acc:8.3f}")
# Out:
# |    20/  100 iteration | loss    0.000 | accuracy    1.000
# |    40/  100 iteration | loss    0.002 | accuracy    1.000
# |    60/  100 iteration | loss    0.007 | accuracy    1.000
# |    80/  100 iteration | loss    0.000 | accuracy    1.000
# Test loss:    0.050 | Test acc:    0.992
